# %%
import pandas as pd
import numpy as np
import pickle
import math

# %%
dataset_name = 'UTS' 


work_path = './' + dataset_name + '/'

file = open('./raw_datasets/' + dataset_name + '/dataset.pickle', 'rb')
dataframe = pickle.load(file)
file.close()


dataframe['coord_z'] = 'NULL'
dataframe['tile'] = 'NULL'
dataframe['user_id'] = 1
dataframe['device_id'] = 1
dataframe['epoch'] = 'NULL'
dataframe['site'] = 'NULL'

dataframe[[x for x in dataframe.columns]] = dataframe[[x for x in dataframe.columns]].replace(100, 'NULL')

dataframe = dataframe[[x for x in dataframe.columns if 'WAP' in x] + ['coord_x', 'coord_y', 'coord_z', 'floor_id', 'building_id', 'site', 'tile', 'user_id', 'device_id', 'epoch', 'set']]
dataframe.reset_index(inplace=True)

dataframe.columns = ['fingerprint_id'] + [x for x in dataframe.columns if 'WAP' in x] + ['coord_x', 'coord_y', 'coord_z', 'floor', 'building', 'site', 'tile', 'user_id', 'device_id', 'epoch', 'set']



# Assigning the logical tiles to the training set fingerprints
# Note that we do not group by also building and floor, since the tile names need not be distinct among the different floors
group_tiles = dataframe[dataframe['set'] != 'test'][['coord_x', 'coord_y', 'set']].groupby(['coord_x', 'coord_y']).count()
coords_map_tile = {}
tile_count = 0
for ind, row in group_tiles.iterrows():
    coords_map_tile[ind] = 'tile_' + str(tile_count)
    tile_count += 1
    
tilevals = []
for ind, row in dataframe.iterrows():
    if row['set'] == 'training':
        tilevals.append(coords_map_tile[(row['coord_x'],row['coord_y'])])
    else:
        tilevals.append('NULL')

dataframe['tile'] = tilevals

        
dataframe
# Out:
#       fingerprint_id WAP001 WAP002 WAP003 WAP004 WAP005 WAP006 WAP007 WAP008  \
# 0                  0   NULL   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 1                  1   NULL   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 2                  2   NULL   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 3                  3   NULL   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 4                  4   NULL   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9491            9491   NULL   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 9492            9492   NULL   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 9493            9493   NULL   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 9494            9494   NULL   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 9495            9495   NULL   NULL   NULL   NULL   NULL   NULL   NULL   NULL
#
#      WAP009  ...  coord_y coord_z floor building  site      tile user_id  \
# 0      NULL  ...  31.0272    NULL    11        0  NULL  tile_439       1
# 1      NULL  ...  31.0272    NULL    11        0  NULL  tile_439       1
# 2      NULL  ...  31.0272    NULL    11        0  NULL  tile_439       1
# 3      NULL  ...  30.7985    NULL    11        0  NULL  tile_427       1
# 4      NULL  ...  30.7985    NULL    11        0  NULL  tile_427       1
# ...     ...  ...      ...     ...   ...      ...   ...       ...     ...
# 9491   NULL  ...  23.1212    NULL     0        0  NULL      NULL       1
# 9492   NULL  ...  23.2927    NULL     0        0  NULL      NULL       1
# 9493   NULL  ...  24.2186    NULL     0        0  NULL      NULL       1
# 9494   NULL  ...  24.1157    NULL     0        0  NULL      NULL       1
# 9495   NULL  ...  25.4989    NULL     0        0  NULL      NULL       1
#
#      device_id epoch       set
# 0            1  NULL  training
# 1            1  NULL  training
# 2            1  NULL  training
# 3            1  NULL  training
# 4            1  NULL  training
# ...        ...   ...       ...
# 9491         1  NULL      test
# 9492         1  NULL      test
# 9493         1  NULL      test
# 9494         1  NULL      test
# 9495         1  NULL      test
#
# [9496 rows x 601 columns]

# %%
# Generating the file places.csv

places = dataframe[['building', 'floor', 'site']].copy().drop_duplicates()
places.reset_index(inplace=True, drop=True)
places['floor_number'] = places['floor']
places = places[['building', 'floor', 'floor_number', 'site']]
places['site_height'] = 'NULL'
places['site_area'] = 'NULL'
places['floor_height'] = 3.7
places['floor_area'] = 'NULL'
places['building_area'] = 'NULL'

for col in places.columns:
    places[col] = places[col].astype(object)

places.to_csv(work_path + '/places.csv', sep=',', na_rep='NULL', index=False)

places
# Out:
#    building floor floor_number  site site_height site_area floor_height  \
# 0         0    11           11  NULL        NULL      NULL          3.7
# 1         0    10           10  NULL        NULL      NULL          3.7
# 2         0     9            9  NULL        NULL      NULL          3.7
# 3         0     8            8  NULL        NULL      NULL          3.7
# 4         0     7            7  NULL        NULL      NULL          3.7
# 5         0     6            6  NULL        NULL      NULL          3.7
# 6         0     5            5  NULL        NULL      NULL          3.7
# 7         0     4            4  NULL        NULL      NULL          3.7
# 8         0     3            3  NULL        NULL      NULL          3.7
# 9         0     2            2  NULL        NULL      NULL          3.7
# 10        0     1            1  NULL        NULL      NULL          3.7
# 11        0     0            0  NULL        NULL      NULL          3.7
# 12        0    12           12  NULL        NULL      NULL          3.7
# 13        0    13           13  NULL        NULL      NULL          3.7
# 14        0    14           14  NULL        NULL      NULL          3.7
# 15        0    15           15  NULL        NULL      NULL          3.7
#
#    floor_area building_area
# 0        NULL          NULL
# 1        NULL          NULL
# 2        NULL          NULL
# 3        NULL          NULL
# 4        NULL          NULL
# 5        NULL          NULL
# 6        NULL          NULL
# 7        NULL          NULL
# 8        NULL          NULL
# 9        NULL          NULL
# 10       NULL          NULL
# 11       NULL          NULL
# 12       NULL          NULL
# 13       NULL          NULL
# 14       NULL          NULL
# 15       NULL          NULL

# %%
# Generating the file tessellations.csv
    

tessellations = dataframe[['building', 'floor', 'site', 'tile']].copy().drop_duplicates()
tessellations['tessellation_type'] = 'logical'


tessellations['coord_a_x'] = 'NULL'
tessellations['coord_a_y'] = 'NULL'
tessellations['coord_b_x'] = 'NULL'
tessellations['coord_b_y'] = 'NULL'
tessellations['coord_c_x'] = 'NULL'
tessellations['coord_c_y'] = 'NULL'
tessellations['coord_d_x'] = 'NULL'
tessellations['coord_d_y'] = 'NULL'
tessellations = tessellations[(tessellations['tile'] != 'NULL')]

tessellations['site'] = 'NULL'

for col in tessellations.columns:
    tessellations[col] = tessellations[col].astype(object)
    

tessellations.to_csv(work_path + '/tessellations.csv', sep=',', na_rep='NULL', index=False)

tessellations
# Out:
#      building floor  site      tile tessellation_type coord_a_x coord_a_y  \
# 0           0    11  NULL  tile_439           logical      NULL      NULL
# 3           0    11  NULL  tile_427           logical      NULL      NULL
# 5           0    11  NULL  tile_426           logical      NULL      NULL
# 8           0    11  NULL  tile_440           logical      NULL      NULL
# 11          0    11  NULL  tile_444           logical      NULL      NULL
# ...       ...   ...   ...       ...               ...       ...       ...
# 9056        0    15  NULL  tile_557           logical      NULL      NULL
# 9067        0    15  NULL  tile_516           logical      NULL      NULL
# 9075        0    15  NULL  tile_475           logical      NULL      NULL
# 9085        0    15  NULL  tile_429           logical      NULL      NULL
# 9095        0    15  NULL  tile_386           logical      NULL      NULL
#
#      coord_b_x coord_b_y coord_c_x coord_c_y coord_d_x coord_d_y
# 0         NULL      NULL      NULL      NULL      NULL      NULL
# 3         NULL      NULL      NULL      NULL      NULL      NULL
# 5         NULL      NULL      NULL      NULL      NULL      NULL
# 8         NULL      NULL      NULL      NULL      NULL      NULL
# 11        NULL      NULL      NULL      NULL      NULL      NULL
# ...        ...       ...       ...       ...       ...       ...
# 9056      NULL      NULL      NULL      NULL      NULL      NULL
# 9067      NULL      NULL      NULL      NULL      NULL      NULL
# 9075      NULL      NULL      NULL      NULL      NULL      NULL
# 9085      NULL      NULL      NULL      NULL      NULL      NULL
# 9095      NULL      NULL      NULL      NULL      NULL      NULL
#
# [1466 rows x 13 columns]

# %%
# Generating the file fingerprints.csv

fingerprints = dataframe[['fingerprint_id', 'coord_x', 'coord_y', 'coord_z', 'user_id', 'device_id', 'epoch', 'set', 'building', 'floor', 'site', 'tile']].copy()
fingerprints['tile_id'] = fingerprints.merge(tessellations, on=['building', 'floor', 'site', 'tile'], how='left', suffixes=('_1', ''))['tile'].fillna('NULL').values
fingerprints = fingerprints[['fingerprint_id', 'coord_x', 'coord_y', 'coord_z', 'building', 'floor', 'site', 'tile', 'user_id', 'device_id', 'epoch', 'set']]
fingerprints['user_id'] = [x if x != 0 else 'NULL' for x in fingerprints['user_id']]
fingerprints['is_radio_map'] = [True if x == 'training' else False for x in fingerprints['set']]
fingerprints['preceded_by'] = 'NULL'
fingerprints['followed_by'] = 'NULL'
fingerprints['notes'] = 'NULL'
fingerprints['site'] = 'NULL'

for col in fingerprints.columns:
    fingerprints[col] = fingerprints[col].astype(object)
    

fingerprints.to_csv(work_path + '/fingerprints.csv', sep=',', na_rep='NULL', index=False)

fingerprints
# Out:
#      fingerprint_id  coord_x  coord_y coord_z building floor  site      tile  \
# 0                 0  40.7871  31.0272    NULL        0    11  NULL  tile_439
# 1                 1  40.7871  31.0272    NULL        0    11  NULL  tile_439
# 2                 2  40.7871  31.0272    NULL        0    11  NULL  tile_439
# 3                 3  39.4464  30.7985    NULL        0    11  NULL  tile_427
# 4                 4  39.4464  30.7985    NULL        0    11  NULL  tile_427
# ...             ...      ...      ...     ...      ...   ...   ...       ...
# 9491           9491  85.0452  23.1212    NULL        0     0  NULL      NULL
# 9492           9492  87.8801  23.2927    NULL        0     0  NULL      NULL
# 9493           9493  90.0977  24.2186    NULL        0     0  NULL      NULL
# 9494           9494   92.201  24.1157    NULL        0     0  NULL      NULL
# 9495           9495  94.0871  25.4989    NULL        0     0  NULL      NULL
#
#      user_id device_id epoch       set is_radio_map preceded_by followed_by  \
# 0          1         1  NULL  training         True        NULL        NULL
# 1          1         1  NULL  training         True        NULL        NULL
# 2          1         1  NULL  training         True        NULL        NULL
# 3          1         1  NULL  training         True        NULL        NULL
# 4          1         1  NULL  training         True        NULL        NULL
# ...      ...       ...   ...       ...          ...         ...         ...
# 9491       1         1  NULL      test        False        NULL        NULL
# 9492       1         1  NULL      test        False        NULL        NULL
# 9493       1         1  NULL      test        False        NULL        NULL
# 9494       1         1  NULL      test        False        NULL        NULL
# 9495       1         1  NULL      test        False        NULL        NULL
#
#      notes
# 0     NULL
# 1     NULL
# 2     NULL
# 3     NULL
# 4     NULL
# ...    ...
# 9491  NULL
# 9492  NULL
# 9493  NULL
# 9494  NULL
# 9495  NULL
#
# [9496 rows x 16 columns]

# %%
# Generating the file wifi_obs.csv

wifi_obs = dataframe[[x for x in dataframe.columns if 'WAP' in x]].copy()
wifi_obs['fingerprint_id'] = dataframe['fingerprint_id']
wifi_obs = wifi_obs[['fingerprint_id'] + [x for x in dataframe.columns if 'WAP' in x]]

for col in wifi_obs.columns:
    wifi_obs[col] = wifi_obs[col].astype(object)
    
wifi_obs.columns = ["AP-" + x + "-NULL" if "WAP" in x else x for x in list(wifi_obs.columns)]

wifi_obs.to_csv(work_path + '/wifi_obs.csv', sep=',', na_rep='NULL', index=False)

wifi_obs
# Out:
#      fingerprint_id AP-WAP001-NULL AP-WAP002-NULL AP-WAP003-NULL  \
# 0                 0           NULL           NULL           NULL
# 1                 1           NULL           NULL           NULL
# 2                 2           NULL           NULL           NULL
# 3                 3           NULL           NULL           NULL
# 4                 4           NULL           NULL           NULL
# ...             ...            ...            ...            ...
# 9491           9491           NULL           NULL           NULL
# 9492           9492           NULL           NULL           NULL
# 9493           9493           NULL           NULL           NULL
# 9494           9494           NULL           NULL           NULL
# 9495           9495           NULL           NULL           NULL
#
#      AP-WAP004-NULL AP-WAP005-NULL AP-WAP006-NULL AP-WAP007-NULL  \
# 0              NULL           NULL           NULL           NULL
# 1              NULL           NULL           NULL           NULL
# 2              NULL           NULL           NULL           NULL
# 3              NULL           NULL           NULL           NULL
# 4              NULL           NULL           NULL           NULL
# ...             ...            ...            ...            ...
# 9491           NULL           NULL           NULL           NULL
# 9492           NULL           NULL           NULL           NULL
# 9493           NULL           NULL           NULL           NULL
# 9494           NULL           NULL           NULL           NULL
# 9495           NULL           NULL           NULL           NULL
#
#      AP-WAP008-NULL AP-WAP009-NULL  ... AP-WAP580-NULL AP-WAP581-NULL  \
# 0              NULL           NULL  ...           NULL           NULL
# 1              NULL           NULL  ...           NULL           NULL
# 2              NULL           NULL  ...           NULL           NULL
# 3              NULL           NULL  ...           NULL           NULL
# 4              NULL           NULL  ...           NULL           NULL
# ...             ...            ...  ...            ...            ...
# 9491           NULL           NULL  ...           NULL           NULL
# 9492           NULL           NULL  ...           NULL           NULL
# 9493           NULL           NULL  ...           NULL           NULL
# 9494           NULL           NULL  ...           NULL           NULL
# 9495           NULL           NULL  ...           NULL           NULL
#
#      AP-WAP582-NULL AP-WAP583-NULL AP-WAP584-NULL AP-WAP585-NULL  \
# 0              NULL           NULL           NULL           NULL
# 1              NULL           NULL           NULL           NULL
# 2              NULL           NULL           NULL           NULL
# 3              NULL           NULL           NULL           NULL
# 4              NULL           NULL           NULL           NULL
# ...             ...            ...            ...            ...
# 9491            -88            -90           NULL           NULL
# 9492           NULL           NULL           NULL           NULL
# 9493           NULL           NULL           NULL           NULL
# 9494           NULL           NULL           NULL           NULL
# 9495           NULL           NULL           NULL           NULL
#
#      AP-WAP586-NULL AP-WAP587-NULL AP-WAP588-NULL AP-WAP589-NULL
# 0              NULL           NULL           NULL           NULL
# 1              NULL           NULL           NULL           NULL
# 2              NULL           NULL           NULL           NULL
# 3              NULL           NULL           NULL           NULL
# 4              NULL           NULL           NULL           NULL
# ...             ...            ...            ...            ...
# 9491           NULL           NULL           NULL           NULL
# 9492           NULL           NULL           NULL           NULL
# 9493           NULL           NULL           NULL           NULL
# 9494           NULL           NULL           NULL           NULL
# 9495           NULL           NULL           NULL           NULL
#
# [9496 rows x 590 columns]
