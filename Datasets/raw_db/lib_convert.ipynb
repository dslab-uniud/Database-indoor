# %%
import pandas as pd
import numpy as np
import pickle

# %%
dataset_name = 'LIB1' # LIB1 # LIB2


work_path = './' + dataset_name + '/'

file = open('./raw_datasets/LIB/' + dataset_name + '/dataset.pickle', 'rb')
dataframe = pickle.load(file)
file.close()


dataframe['coord_z'] = 'NULL'
dataframe['building_id'] = 'library'
dataframe['site'] = 'main_room'
dataframe['tile'] = 'single_tile'
dataframe['user_id'] = 1
dataframe['device_id'] = 1
dataframe['epoch'] = 'NULL'

dataframe[[x for x in dataframe.columns]] = dataframe[[x for x in dataframe.columns]].replace(100, 'NULL')

dataframe = dataframe[[x for x in dataframe.columns if 'WAP' in x] + ['coord_x', 'coord_y', 'coord_z', 'floor_id', 'building_id', 'site', 'tile', 'user_id', 'device_id', 'epoch', 'set']]
dataframe.reset_index(inplace=True)

dataframe.columns = ['fingerprint_id'] + [x for x in dataframe.columns if 'WAP' in x] + ['coord_x', 'coord_y', 'coord_z', 'floor', 'building', 'site', 'tile', 'user_id', 'device_id', 'epoch', 'set']


# Assigning the logical tiles to the training set fingerprints
# Note that we do not group by also building and floor, since the tile names need not be distinct among the different floors
group_tiles = dataframe[dataframe['set'] != 'test'][['coord_x', 'coord_y', 'set']].groupby(['coord_x', 'coord_y']).count()
coords_map_tile = {}
tile_count = 0
for ind, row in group_tiles.iterrows():
    coords_map_tile[ind] = 'tile_' + str(tile_count)
    tile_count += 1
    
tilevals = []
for ind, row in dataframe.iterrows():
    if row['set'] == 'training':
        tilevals.append(coords_map_tile[(row['coord_x'],row['coord_y'])])
    else:
        tilevals.append('NULL')

dataframe['tile'] = tilevals


dataframe
# Out:
#       fingerprint_id WAP000 WAP001 WAP002 WAP003 WAP004 WAP005 WAP006 WAP007  \
# 0                  0    -84    -53    -58    -85    -84    -85    -58    -86
# 1                  1    -82    -52    -56   NULL    -86    -83    -55    -87
# 2                  2    -83    -51    -60    -90    -83    -81    -58    -90
# 3                  3    -84    -50    -57    -89    -84    -81    -56    -89
# 4                  4    -82    -53    -56    -90    -88    -83    -58    -91
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 3691            3691   NULL   NULL   NULL   NULL   NULL    -92    -83   NULL
# 3692            3692   NULL   NULL   NULL   NULL   NULL    -85   NULL   NULL
# 3693            3693   NULL   NULL   NULL   NULL   NULL    -84    -84    -82
# 3694            3694   NULL   NULL   NULL   NULL   NULL    -85   NULL    -78
# 3695            3695   NULL   NULL   NULL   NULL   NULL    -83    -81   NULL
#
#      WAP008  ...    coord_y coord_z floor building       site     tile  \
# 0       -52  ...  29.207532    NULL     3  library  main_room  tile_23
# 1       -50  ...  29.207532    NULL     3  library  main_room  tile_23
# 2       -52  ...  29.207532    NULL     3  library  main_room  tile_23
# 3       -52  ...  29.207532    NULL     3  library  main_room  tile_23
# 4       -52  ...  29.207532    NULL     3  library  main_room  tile_23
# ...     ...  ...        ...     ...   ...      ...        ...      ...
# 3691    -87  ...  29.207532    NULL     5  library  main_room     NULL
# 3692   NULL  ...  29.207532    NULL     5  library  main_room     NULL
# 3693    -87  ...  29.207532    NULL     5  library  main_room     NULL
# 3694    -88  ...  29.207532    NULL     5  library  main_room     NULL
# 3695    -87  ...  29.207532    NULL     5  library  main_room     NULL
#
#      user_id device_id epoch       set
# 0          1         1  NULL  training
# 1          1         1  NULL  training
# 2          1         1  NULL  training
# 3          1         1  NULL  training
# 4          1         1  NULL  training
# ...      ...       ...   ...       ...
# 3691       1         1  NULL      test
# 3692       1         1  NULL      test
# 3693       1         1  NULL      test
# 3694       1         1  NULL      test
# 3695       1         1  NULL      test
#
# [3696 rows x 209 columns]

# %%
# Generating the file places.csv

places = dataframe[['building', 'floor', 'site']].copy().drop_duplicates()
places.reset_index(inplace=True, drop=True)
places['floor_number'] = places['floor']
places = places[['building', 'floor', 'floor_number', 'site']]
places['site_height'] = 2.65
places['site_area'] = 'NULL'
places['floor_height'] = 2.65
places['floor_area'] = 'NULL'
places['building_area'] = 'NULL'

for col in places.columns:
    places[col] = places[col].astype(object)

places.to_csv(work_path + '/places.csv', sep=',', na_rep='NULL', index=False)

places
# Out:
#   building floor floor_number       site site_height site_area floor_height  \
# 0  library     3            3  main_room        2.65      NULL         2.65
# 1  library     5            5  main_room        2.65      NULL         2.65
#
#   floor_area building_area
# 0       NULL          NULL
# 1       NULL          NULL

# %%
# Generating the file tessellations.csv

tessellations = dataframe[['building', 'floor', 'site', 'tile']].copy().drop_duplicates()
tessellations['tessellation_type'] = 'logical'
tessellations['coord_a_x'] = 'NULL'
tessellations['coord_a_y'] = 'NULL'
tessellations['coord_b_x'] = 'NULL'
tessellations['coord_b_y'] = 'NULL'
tessellations['coord_c_x'] = 'NULL'
tessellations['coord_c_y'] = 'NULL'
tessellations['coord_d_x'] = 'NULL'
tessellations['coord_d_y'] = 'NULL'
tessellations = tessellations[(tessellations['tile'] != 'NULL')]


for col in tessellations.columns:
    tessellations[col] = tessellations[col].astype(object)
    

tessellations.to_csv(work_path + '/tessellations.csv', sep=',', na_rep='NULL', index=False)

tessellations
# Out:
#     building floor       site     tile tessellation_type coord_a_x coord_a_y  \
# 0    library     3  main_room  tile_23           logical      NULL      NULL
# 6    library     3  main_room  tile_15           logical      NULL      NULL
# 12   library     3  main_room   tile_7           logical      NULL      NULL
# 18   library     3  main_room  tile_22           logical      NULL      NULL
# 24   library     3  main_room  tile_14           logical      NULL      NULL
# 30   library     3  main_room   tile_6           logical      NULL      NULL
# 36   library     3  main_room  tile_21           logical      NULL      NULL
# 42   library     3  main_room  tile_13           logical      NULL      NULL
# 48   library     3  main_room   tile_5           logical      NULL      NULL
# 54   library     3  main_room  tile_20           logical      NULL      NULL
# 60   library     3  main_room  tile_12           logical      NULL      NULL
# 66   library     3  main_room   tile_4           logical      NULL      NULL
# 72   library     3  main_room  tile_19           logical      NULL      NULL
# 78   library     3  main_room  tile_11           logical      NULL      NULL
# 84   library     3  main_room   tile_3           logical      NULL      NULL
# 90   library     3  main_room  tile_18           logical      NULL      NULL
# 96   library     3  main_room  tile_10           logical      NULL      NULL
# 102  library     3  main_room   tile_2           logical      NULL      NULL
# 108  library     3  main_room  tile_17           logical      NULL      NULL
# 114  library     3  main_room   tile_9           logical      NULL      NULL
# 120  library     3  main_room   tile_1           logical      NULL      NULL
# 126  library     3  main_room  tile_16           logical      NULL      NULL
# 132  library     3  main_room   tile_8           logical      NULL      NULL
# 138  library     3  main_room   tile_0           logical      NULL      NULL
# 288  library     5  main_room  tile_23           logical      NULL      NULL
# 294  library     5  main_room  tile_15           logical      NULL      NULL
# 300  library     5  main_room   tile_7           logical      NULL      NULL
# 306  library     5  main_room  tile_22           logical      NULL      NULL
# 312  library     5  main_room  tile_14           logical      NULL      NULL
# 318  library     5  main_room   tile_6           logical      NULL      NULL
# 324  library     5  main_room  tile_21           logical      NULL      NULL
# 330  library     5  main_room  tile_13           logical      NULL      NULL
# 336  library     5  main_room   tile_5           logical      NULL      NULL
# 342  library     5  main_room  tile_20           logical      NULL      NULL
# 348  library     5  main_room  tile_12           logical      NULL      NULL
# 354  library     5  main_room   tile_4           logical      NULL      NULL
# 360  library     5  main_room  tile_19           logical      NULL      NULL
# 366  library     5  main_room  tile_11           logical      NULL      NULL
# 372  library     5  main_room   tile_3           logical      NULL      NULL
# 378  library     5  main_room  tile_18           logical      NULL      NULL
# 384  library     5  main_room  tile_10           logical      NULL      NULL
# 390  library     5  main_room   tile_2           logical      NULL      NULL
# 396  library     5  main_room  tile_17           logical      NULL      NULL
# 402  library     5  main_room   tile_9           logical      NULL      NULL
# 408  library     5  main_room   tile_1           logical      NULL      NULL
# 414  library     5  main_room  tile_16           logical      NULL      NULL
# 420  library     5  main_room   tile_8           logical      NULL      NULL
# 426  library     5  main_room   tile_0           logical      NULL      NULL
#
#     coord_b_x coord_b_y coord_c_x coord_c_y coord_d_x coord_d_y
# 0        NULL      NULL      NULL      NULL      NULL      NULL
# 6        NULL      NULL      NULL      NULL      NULL      NULL
# 12       NULL      NULL      NULL      NULL      NULL      NULL
# 18       NULL      NULL      NULL      NULL      NULL      NULL
# 24       NULL      NULL      NULL      NULL      NULL      NULL
# 30       NULL      NULL      NULL      NULL      NULL      NULL
# 36       NULL      NULL      NULL      NULL      NULL      NULL
# 42       NULL      NULL      NULL      NULL      NULL      NULL
# 48       NULL      NULL      NULL      NULL      NULL      NULL
# 54       NULL      NULL      NULL      NULL      NULL      NULL
# 60       NULL      NULL      NULL      NULL      NULL      NULL
# 66       NULL      NULL      NULL      NULL      NULL      NULL
# 72       NULL      NULL      NULL      NULL      NULL      NULL
# 78       NULL      NULL      NULL      NULL      NULL      NULL
# 84       NULL      NULL      NULL      NULL      NULL      NULL
# 90       NULL      NULL      NULL      NULL      NULL      NULL
# 96       NULL      NULL      NULL      NULL      NULL      NULL
# 102      NULL      NULL      NULL      NULL      NULL      NULL
# 108      NULL      NULL      NULL      NULL      NULL      NULL
# 114      NULL      NULL      NULL      NULL      NULL      NULL
# 120      NULL      NULL      NULL      NULL      NULL      NULL
# 126      NULL      NULL      NULL      NULL      NULL      NULL
# 132      NULL      NULL      NULL      NULL      NULL      NULL
# 138      NULL      NULL      NULL      NULL      NULL      NULL
# 288      NULL      NULL      NULL      NULL      NULL      NULL
# 294      NULL      NULL      NULL      NULL      NULL      NULL
# 300      NULL      NULL      NULL      NULL      NULL      NULL
# 306      NULL      NULL      NULL      NULL      NULL      NULL
# 312      NULL      NULL      NULL      NULL      NULL      NULL
# 318      NULL      NULL      NULL      NULL      NULL      NULL
# 324      NULL      NULL      NULL      NULL      NULL      NULL
# 330      NULL      NULL      NULL      NULL      NULL      NULL
# 336      NULL      NULL      NULL      NULL      NULL      NULL
# 342      NULL      NULL      NULL      NULL      NULL      NULL
# 348      NULL      NULL      NULL      NULL      NULL      NULL
# 354      NULL      NULL      NULL      NULL      NULL      NULL
# 360      NULL      NULL      NULL      NULL      NULL      NULL
# 366      NULL      NULL      NULL      NULL      NULL      NULL
# 372      NULL      NULL      NULL      NULL      NULL      NULL
# 378      NULL      NULL      NULL      NULL      NULL      NULL
# 384      NULL      NULL      NULL      NULL      NULL      NULL
# 390      NULL      NULL      NULL      NULL      NULL      NULL
# 396      NULL      NULL      NULL      NULL      NULL      NULL
# 402      NULL      NULL      NULL      NULL      NULL      NULL
# 408      NULL      NULL      NULL      NULL      NULL      NULL
# 414      NULL      NULL      NULL      NULL      NULL      NULL
# 420      NULL      NULL      NULL      NULL      NULL      NULL
# 426      NULL      NULL      NULL      NULL      NULL      NULL

# %%
# Generating the file fingerprints.csv

fingerprints = dataframe[['fingerprint_id', 'coord_x', 'coord_y', 'coord_z', 'user_id', 'device_id', 'epoch', 'set', 'building', 'floor', 'site', 'tile']].copy()
fingerprints['tile_id'] = fingerprints.merge(tessellations, on=['building', 'floor', 'site', 'tile'], how='left', suffixes=('_1', ''))['tile'].fillna('NULL').values
fingerprints = fingerprints[['fingerprint_id', 'coord_x', 'coord_y', 'coord_z', 'building', 'floor', 'site', 'tile', 'user_id', 'device_id', 'epoch', 'set']]
fingerprints['user_id'] = [x if x != 0 else 'NULL' for x in fingerprints['user_id']]
fingerprints['is_radio_map'] = [True if x == 'training' else False for x in fingerprints['set']]
fingerprints['preceded_by'] = 'NULL'
fingerprints['followed_by'] = 'NULL'
fingerprints['notes'] = 'NULL'

for col in fingerprints.columns:
    fingerprints[col] = fingerprints[col].astype(object)
    

fingerprints.to_csv(work_path + '/fingerprints.csv', sep=',', na_rep='NULL', index=False)

fingerprints
# Out:
#      fingerprint_id  coord_x  coord_y coord_z building floor       site  \
# 0                 0  12.9045  29.2075    NULL  library     3  main_room
# 1                 1  12.9045  29.2075    NULL  library     3  main_room
# 2                 2  12.9045  29.2075    NULL  library     3  main_room
# 3                 3  12.9045  29.2075    NULL  library     3  main_room
# 4                 4  12.9045  29.2075    NULL  library     3  main_room
# ...             ...      ...      ...     ...      ...   ...        ...
# 3691           3691  12.9045  29.2075    NULL  library     5  main_room
# 3692           3692  12.9045  29.2075    NULL  library     5  main_room
# 3693           3693  12.9045  29.2075    NULL  library     5  main_room
# 3694           3694  12.9045  29.2075    NULL  library     5  main_room
# 3695           3695  12.9045  29.2075    NULL  library     5  main_room
#
#          tile user_id device_id epoch       set is_radio_map preceded_by  \
# 0     tile_23       1         1  NULL  training         True        NULL
# 1     tile_23       1         1  NULL  training         True        NULL
# 2     tile_23       1         1  NULL  training         True        NULL
# 3     tile_23       1         1  NULL  training         True        NULL
# 4     tile_23       1         1  NULL  training         True        NULL
# ...       ...     ...       ...   ...       ...          ...         ...
# 3691     NULL       1         1  NULL      test        False        NULL
# 3692     NULL       1         1  NULL      test        False        NULL
# 3693     NULL       1         1  NULL      test        False        NULL
# 3694     NULL       1         1  NULL      test        False        NULL
# 3695     NULL       1         1  NULL      test        False        NULL
#
#      followed_by notes
# 0           NULL  NULL
# 1           NULL  NULL
# 2           NULL  NULL
# 3           NULL  NULL
# 4           NULL  NULL
# ...          ...   ...
# 3691        NULL  NULL
# 3692        NULL  NULL
# 3693        NULL  NULL
# 3694        NULL  NULL
# 3695        NULL  NULL
#
# [3696 rows x 16 columns]

# %%
# Generating the file wifi_obs.csv

wifi_obs = dataframe[[x for x in dataframe.columns if 'WAP' in x]].copy()
wifi_obs['fingerprint_id'] = dataframe['fingerprint_id']
wifi_obs = wifi_obs[['fingerprint_id'] + [x for x in dataframe.columns if 'WAP' in x]]

for col in wifi_obs.columns:
    wifi_obs[col] = wifi_obs[col].astype(object)
    
wifi_obs.columns = ["AP-" + x + "-NULL" if "WAP" in x else x for x in list(wifi_obs.columns)]

wifi_obs.to_csv(work_path + '/wifi_obs.csv', sep=',', na_rep='NULL', index=False)

wifi_obs
# Out:
#      fingerprint_id AP-WAP000-NULL AP-WAP001-NULL AP-WAP002-NULL  \
# 0                 0            -84            -53            -58
# 1                 1            -82            -52            -56
# 2                 2            -83            -51            -60
# 3                 3            -84            -50            -57
# 4                 4            -82            -53            -56
# ...             ...            ...            ...            ...
# 3691           3691           NULL           NULL           NULL
# 3692           3692           NULL           NULL           NULL
# 3693           3693           NULL           NULL           NULL
# 3694           3694           NULL           NULL           NULL
# 3695           3695           NULL           NULL           NULL
#
#      AP-WAP003-NULL AP-WAP004-NULL AP-WAP005-NULL AP-WAP006-NULL  \
# 0               -85            -84            -85            -58
# 1              NULL            -86            -83            -55
# 2               -90            -83            -81            -58
# 3               -89            -84            -81            -56
# 4               -90            -88            -83            -58
# ...             ...            ...            ...            ...
# 3691           NULL           NULL            -92            -83
# 3692           NULL           NULL            -85           NULL
# 3693           NULL           NULL            -84            -84
# 3694           NULL           NULL            -85           NULL
# 3695           NULL           NULL            -83            -81
#
#      AP-WAP007-NULL AP-WAP008-NULL  ... AP-WAP187-NULL AP-WAP188-NULL  \
# 0               -86            -52  ...           NULL           NULL
# 1               -87            -50  ...           NULL           NULL
# 2               -90            -52  ...           NULL           NULL
# 3               -89            -52  ...           NULL           NULL
# 4               -91            -52  ...           NULL           NULL
# ...             ...            ...  ...            ...            ...
# 3691           NULL            -87  ...           NULL           NULL
# 3692           NULL           NULL  ...           NULL           NULL
# 3693            -82            -87  ...           NULL           NULL
# 3694            -78            -88  ...           NULL           NULL
# 3695           NULL            -87  ...           NULL           NULL
#
#      AP-WAP189-NULL AP-WAP190-NULL AP-WAP191-NULL AP-WAP192-NULL  \
# 0              NULL           NULL           NULL           NULL
# 1              NULL           NULL           NULL           NULL
# 2              NULL           NULL           NULL           NULL
# 3              NULL           NULL           NULL           NULL
# 4              NULL           NULL           NULL           NULL
# ...             ...            ...            ...            ...
# 3691           NULL           NULL           NULL           NULL
# 3692           NULL           NULL           NULL           NULL
# 3693           NULL           NULL           NULL           NULL
# 3694           NULL           NULL           NULL           NULL
# 3695           NULL           NULL           NULL           NULL
#
#      AP-WAP193-NULL AP-WAP194-NULL AP-WAP195-NULL AP-WAP196-NULL
# 0              NULL           NULL           NULL           NULL
# 1              NULL           NULL           NULL           NULL
# 2              NULL           NULL           NULL           NULL
# 3              NULL           NULL           NULL           NULL
# 4              NULL           NULL           NULL           NULL
# ...             ...            ...            ...            ...
# 3691           NULL           NULL           NULL           NULL
# 3692            -69           NULL           NULL           NULL
# 3693            -72           NULL           NULL           NULL
# 3694            -72           NULL           NULL           NULL
# 3695           NULL           NULL           NULL           NULL
#
# [3696 rows x 198 columns]
