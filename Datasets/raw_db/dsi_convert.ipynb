# %%
import pandas as pd
import numpy as np
import pickle

# %%
# This first part of the procedure works for both DSI1 and DSI2 datasets
# Later in the code, there is the part to import DSI-trajectories

# %%
dataset_name = 'DSI1' # DSI1 # DSI2


work_path = './' + dataset_name

file = open('./raw_datasets/DSI/' + dataset_name + '/dataset.pickle', 'rb')
dataframe = pickle.load(file)
file.close()


dataframe['coord_z'] = 'NULL'
dataframe['building_id'] = '11'
dataframe['site'] = 'NULL'
dataframe['tile'] = 'NULL'
dataframe['user_id'] = 1
dataframe['device_id'] = 1
dataframe['epoch'] = 'NULL'

dataframe[[x for x in dataframe.columns]] = dataframe[[x for x in dataframe.columns]].replace(100, 'NULL')

dataframe = dataframe[[x for x in dataframe.columns if 'WAP' in x] + ['coord_x', 'coord_y', 'coord_z', 'floor_id', 'building_id', 'site', 'tile', 'user_id', 'device_id', 'epoch', 'set']]
dataframe.reset_index(inplace=True)

dataframe.columns = ['fingerprint_id'] + [x for x in dataframe.columns if 'WAP' in x] + ['coord_x', 'coord_y', 'coord_z', 'floor', 'building', 'site', 'tile', 'user_id', 'device_id', 'epoch', 'set']


# Assigning the logical tiles to the training set fingerprints
# Note that we do not group by also building and floor, since the tile names need not be distinct among the different floors. In any case, here I have just a single floor.
group_tiles = dataframe[dataframe['set'] != 'test'][['coord_x', 'coord_y', 'set']].groupby(['coord_x', 'coord_y']).count()
coords_map_tile = {}
tile_count = 0
for ind, row in group_tiles.iterrows():
    coords_map_tile[ind] = 'tile_' + str(tile_count)
    tile_count += 1
    
tilevals = []
for ind, row in dataframe.iterrows():
    if row['set'] == 'training':
        tilevals.append(coords_map_tile[(row['coord_x'],row['coord_y'])])
    else:
        tilevals.append('NULL')

dataframe['tile'] = tilevals

        
dataframe
# Out:
#       fingerprint_id WAP000 WAP001 WAP002 WAP003 WAP004 WAP005 WAP006 WAP007  \
# 0                  0    -53   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 1                  1    -53   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 2                  2    -53   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 3                  3    -58   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 4                  4    -58   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1712            1712    -78   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 1713            1713    -79   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 1714            1714    -79   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 1715            1715    -64   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 1716            1716    -64   NULL   NULL   NULL   NULL   NULL   NULL   NULL
#
#      WAP008  ...    coord_y coord_z floor building  site      tile user_id  \
# 0      NULL  ...  54.633661    NULL     1       11  NULL  tile_178       1
# 1      NULL  ...  54.633661    NULL     1       11  NULL  tile_178       1
# 2      NULL  ...  54.633661    NULL     1       11  NULL  tile_178       1
# 3      NULL  ...  53.462735    NULL     1       11  NULL  tile_192       1
# 4      NULL  ...  53.462735    NULL     1       11  NULL  tile_192       1
# ...     ...  ...        ...     ...   ...      ...   ...       ...     ...
# 1712   NULL  ...  71.326591    NULL     1       11  NULL      NULL       1
# 1713   NULL  ...  73.526635    NULL     1       11  NULL      NULL       1
# 1714   NULL  ...  74.395074    NULL     1       11  NULL      NULL       1
# 1715   NULL  ...  73.902958    NULL     1       11  NULL      NULL       1
# 1716   NULL  ...  72.428346    NULL     1       11  NULL      NULL       1
#
#      device_id epoch       set
# 0            1  NULL  training
# 1            1  NULL  training
# 2            1  NULL  training
# 3            1  NULL  training
# 4            1  NULL  training
# ...        ...   ...       ...
# 1712         1  NULL      test
# 1713         1  NULL      test
# 1714         1  NULL      test
# 1715         1  NULL      test
# 1716         1  NULL      test
#
# [1717 rows x 169 columns]

# %%
# Generating the file places.csv

places = dataframe[['building', 'floor', 'site']].copy().drop_duplicates()
places.reset_index(inplace=True, drop=True)
places['floor_number'] = places['floor']
places = places[['building', 'floor', 'floor_number', 'site']]
places['site_height'] = 'NULL'
places['site_area'] = 'NULL'
places['floor_height'] = 3.7
places['floor_area'] = 'NULL'
places['building_area'] = 'NULL'

for col in places.columns:
    places[col] = places[col].astype(object)

places.to_csv(work_path + '/places.csv', sep=',', na_rep='NULL', index=False)

places
# Out:
#   building floor floor_number  site site_height site_area floor_height  \
# 0       11     1            1  NULL        NULL      NULL          3.7
#
#   floor_area building_area
# 0       NULL          NULL

# %%
# Generating the file tessellations.csv

tessellations = dataframe[['building', 'floor', 'site', 'tile']].copy().drop_duplicates()
tessellations['tessellation_type'] = 'logical'
tessellations['coord_a_x'] = 'NULL'
tessellations['coord_a_y'] = 'NULL'
tessellations['coord_b_x'] = 'NULL'
tessellations['coord_b_y'] = 'NULL'
tessellations['coord_c_x'] = 'NULL'
tessellations['coord_c_y'] = 'NULL'
tessellations['coord_d_x'] = 'NULL'
tessellations['coord_d_y'] = 'NULL'
tessellations = tessellations[(tessellations['tile'] != 'NULL')]


for col in tessellations.columns:
    tessellations[col] = tessellations[col].astype(object)
    

tessellations.to_csv(work_path + '/tessellations.csv', sep=',', na_rep='NULL', index=False)

tessellations
# Out:
#     building floor  site      tile tessellation_type coord_a_x coord_a_y  \
# 0         11     1  NULL  tile_178           logical      NULL      NULL
# 2         11     1  NULL  tile_192           logical      NULL      NULL
# 5         11     1  NULL  tile_197           logical      NULL      NULL
# 8         11     1  NULL  tile_199           logical      NULL      NULL
# 11        11     1  NULL  tile_224           logical      NULL      NULL
# ..       ...   ...   ...       ...               ...       ...       ...
# 568       11     1  NULL  tile_115           logical      NULL      NULL
# 569       11     1  NULL  tile_111           logical      NULL      NULL
# 571       11     1  NULL  tile_114           logical      NULL      NULL
# 573       11     1  NULL  tile_121           logical      NULL      NULL
# 574       11     1  NULL  tile_125           logical      NULL      NULL
#
#     coord_b_x coord_b_y coord_c_x coord_c_y coord_d_x coord_d_y
# 0        NULL      NULL      NULL      NULL      NULL      NULL
# 2        NULL      NULL      NULL      NULL      NULL      NULL
# 5        NULL      NULL      NULL      NULL      NULL      NULL
# 8        NULL      NULL      NULL      NULL      NULL      NULL
# 11       NULL      NULL      NULL      NULL      NULL      NULL
# ..        ...       ...       ...       ...       ...       ...
# 568      NULL      NULL      NULL      NULL      NULL      NULL
# 569      NULL      NULL      NULL      NULL      NULL      NULL
# 571      NULL      NULL      NULL      NULL      NULL      NULL
# 573      NULL      NULL      NULL      NULL      NULL      NULL
# 574      NULL      NULL      NULL      NULL      NULL      NULL
#
# [230 rows x 13 columns]

# %%
# Generating the file fingerprints.csv

fingerprints = dataframe[['fingerprint_id', 'coord_x', 'coord_y', 'coord_z', 'user_id', 'device_id', 'epoch', 'set', 'building', 'floor', 'site', 'tile']].copy()
fingerprints['tile_id'] = fingerprints.merge(tessellations, on=['building', 'floor', 'site', 'tile'], how='left', suffixes=('_1', ''))['tile'].fillna('NULL').values
fingerprints = fingerprints[['fingerprint_id', 'coord_x', 'coord_y', 'coord_z', 'building', 'floor', 'site', 'tile', 'user_id', 'device_id', 'epoch', 'set']]
fingerprints['user_id'] = [x if x != 0 else 'NULL' for x in fingerprints['user_id']]
fingerprints['is_radio_map'] = [True if x == 'training' else False for x in fingerprints['set']]
fingerprints['preceded_by'] = 'NULL'
fingerprints['followed_by'] = 'NULL'
fingerprints['notes'] = 'NULL'

for col in fingerprints.columns:
    fingerprints[col] = fingerprints[col].astype(object)
    

fingerprints.to_csv(work_path + '/fingerprints.csv', sep=',', na_rep='NULL', index=False)

fingerprints
# Out:
#     fingerprint_id  coord_x  coord_y coord_z building floor  site      tile  \
# 0                0  73.7565  54.6337    NULL       11     1  NULL  tile_178
# 1                1  73.7565  54.6337    NULL       11     1  NULL  tile_178
# 2                2  76.1996  53.4627    NULL       11     1  NULL  tile_192
# 3                3  76.1996  53.4627    NULL       11     1  NULL  tile_192
# 4                4  76.1996  53.4627    NULL       11     1  NULL  tile_192
# ..             ...      ...      ...     ...      ...   ...   ...       ...
# 919            919  67.5547  71.3266    NULL       11     1  NULL      NULL
# 920            920  70.7535  73.5266    NULL       11     1  NULL      NULL
# 921            921  72.5338  74.3951    NULL       11     1  NULL      NULL
# 922            922  79.2209   73.903    NULL       11     1  NULL      NULL
# 923            923  80.2994  72.4283    NULL       11     1  NULL      NULL
#
#     user_id device_id epoch       set is_radio_map preceded_by followed_by  \
# 0         1         1  NULL  training         True        NULL        NULL
# 1         1         1  NULL  training         True        NULL        NULL
# 2         1         1  NULL  training         True        NULL        NULL
# 3         1         1  NULL  training         True        NULL        NULL
# 4         1         1  NULL  training         True        NULL        NULL
# ..      ...       ...   ...       ...          ...         ...         ...
# 919       1         1  NULL      test        False        NULL        NULL
# 920       1         1  NULL      test        False        NULL        NULL
# 921       1         1  NULL      test        False        NULL        NULL
# 922       1         1  NULL      test        False        NULL        NULL
# 923       1         1  NULL      test        False        NULL        NULL
#
#     notes
# 0    NULL
# 1    NULL
# 2    NULL
# 3    NULL
# 4    NULL
# ..    ...
# 919  NULL
# 920  NULL
# 921  NULL
# 922  NULL
# 923  NULL
#
# [924 rows x 16 columns]

# %%
# Generating the file wifi_obs.csv

wifi_obs = dataframe[[x for x in dataframe.columns if 'WAP' in x]].copy()
wifi_obs['fingerprint_id'] = dataframe['fingerprint_id']
wifi_obs = wifi_obs[['fingerprint_id'] + [x for x in dataframe.columns if 'WAP' in x]]

for col in wifi_obs.columns:
    wifi_obs[col] = wifi_obs[col].astype(object)
    
wifi_obs.columns = ["AP-" + x + "-NULL" if "WAP" in x else x for x in list(wifi_obs.columns)]

wifi_obs.to_csv(work_path + '/wifi_obs.csv', sep=',', na_rep='NULL', index=False)

wifi_obs
# Out:
#     fingerprint_id AP-WAP000-NULL AP-WAP001-NULL AP-WAP002-NULL  \
# 0                0            -53           NULL           NULL
# 1                1            -53           NULL           NULL
# 2                2            -58           NULL           NULL
# 3                3            -58           NULL           NULL
# 4                4            -58           NULL           NULL
# ..             ...            ...            ...            ...
# 919            919            -78           NULL           NULL
# 920            920            -79           NULL           NULL
# 921            921            -79           NULL           NULL
# 922            922            -64           NULL           NULL
# 923            923            -64           NULL           NULL
#
#     AP-WAP003-NULL AP-WAP004-NULL AP-WAP005-NULL AP-WAP006-NULL  \
# 0             NULL           NULL           NULL           NULL
# 1             NULL           NULL           NULL           NULL
# 2             NULL           NULL           NULL           NULL
# 3             NULL           NULL           NULL           NULL
# 4             NULL           NULL           NULL           NULL
# ..             ...            ...            ...            ...
# 919           NULL           NULL           NULL           NULL
# 920           NULL           NULL           NULL           NULL
# 921           NULL           NULL           NULL           NULL
# 922           NULL           NULL           NULL           NULL
# 923           NULL           NULL           NULL           NULL
#
#     AP-WAP007-NULL AP-WAP008-NULL  ... AP-WAP147-NULL AP-WAP148-NULL  \
# 0             NULL           NULL  ...           NULL           NULL
# 1             NULL           NULL  ...           NULL           NULL
# 2             NULL           NULL  ...           NULL           NULL
# 3             NULL           NULL  ...           NULL           NULL
# 4             NULL           NULL  ...           NULL           NULL
# ..             ...            ...  ...            ...            ...
# 919           NULL           NULL  ...            -87           NULL
# 920           NULL           NULL  ...           NULL           NULL
# 921           NULL           NULL  ...           NULL           NULL
# 922           NULL           NULL  ...           NULL           NULL
# 923           NULL           NULL  ...           NULL           NULL
#
#     AP-WAP149-NULL AP-WAP150-NULL AP-WAP151-NULL AP-WAP152-NULL  \
# 0             NULL           NULL           NULL           NULL
# 1             NULL           NULL           NULL           NULL
# 2             NULL           NULL           NULL           NULL
# 3             NULL           NULL           NULL           NULL
# 4             NULL           NULL           NULL           NULL
# ..             ...            ...            ...            ...
# 919           NULL           NULL            -96           NULL
# 920           NULL           NULL           NULL           NULL
# 921           NULL           NULL           NULL           NULL
# 922           NULL           NULL           NULL           NULL
# 923           NULL           NULL           NULL           NULL
#
#     AP-WAP153-NULL AP-WAP154-NULL AP-WAP155-NULL AP-WAP156-NULL
# 0             NULL           NULL           NULL           NULL
# 1             NULL           NULL           NULL           NULL
# 2             NULL           NULL           NULL           NULL
# 3             NULL           NULL           NULL           NULL
# 4             NULL           NULL           NULL           NULL
# ..             ...            ...            ...            ...
# 919           NULL           NULL           NULL           NULL
# 920           NULL           NULL           NULL           NULL
# 921           NULL           NULL           NULL           NULL
# 922           NULL           NULL           NULL           NULL
# 923           NULL           NULL           NULL           NULL
#
# [924 rows x 158 columns]

# %%
#                                                                                                   #
#                                                                                                   #
################################## PART TO IMPORT DSI-TRAJECTORIES ################################## 
#                                                                                                   #
#                                                                                                   #

# %%
dataset_name = 'DSI_trajectories'

work_path = './' + dataset_name


# Reading the RM files; they just contain the train portion of DSI1 and such info is not needed, but we are still reading it

coords = pd.read_csv('./raw_datasets/DSI/' + dataset_name  + '/rm_crd.csv', header=None)
coords.columns = ['coord_x', 'coord_y']
coords['coord_z'] = 'NULL'
coords['floor'] = 1
coords['building'] = 11
coords['site'] = 'NULL'
coords['tile'] = 'crowd_tile_1'

rss = pd.read_csv('./raw_datasets/DSI/' + dataset_name  + '/rm_rss.csv', header=None)
rss[[x for x in rss.columns]] = rss[[x for x in rss.columns]].replace(-150, 'NULL')
rss.reset_index(inplace=True)
rss.columns = ['fingerprint_id'] + ['WAP' + '000'[len(str(x)):] + str(x) for x in rss.columns if x != 'index']

ep = pd.read_csv('./raw_datasets/DSI/' + dataset_name  + '/rm_tms.csv', header=None)
ep.columns = ['epoch']

dataframe_train_part_dsi1 = pd.concat([rss, coords], axis=1)
dataframe_train_part_dsi1['user_id'] = 1
dataframe_train_part_dsi1['device_id'] = 1
dataframe_train_part_dsi1 = pd.concat([dataframe_train_part_dsi1, ep], axis=1)
dataframe_train_part_dsi1['set'] = 'training'


# Reading the TJ files

dataframe = pd.read_csv('./raw_datasets/DSI/' + dataset_name  + '/tj_crd.csv', header=None)
dataframe.columns = ['coord_x', 'coord_y']
dataframe['coord_z'] = 'NULL'
dataframe['floor'] = 1
dataframe['building'] = 11
dataframe['site'] = 'NULL'
dataframe['tile'] = 'crowd_tile_1'
dataframe['user_id'] = 1
dataframe['device_id'] = 1

rss = pd.read_csv('./raw_datasets/DSI/' + dataset_name  + '/tj_rss.csv', header=None)
rss[[x for x in rss.columns]] = rss[[x for x in rss.columns]].replace(-150, 'NULL')
rss.reset_index(inplace=True)
rss.columns = ['fingerprint_id'] + ['WAP' + '000'[len(str(x)):] + str(x) for x in rss.columns if x != 'index']

ep = pd.read_csv('./raw_datasets/DSI/' + dataset_name  + '/tj_tms.csv', header=None)
ep.columns = ['epoch']
ep['set'] = 'training'

dataframe = pd.concat([rss, dataframe, ep], axis=1)
dataframe
# Out:
#      fingerprint_id WAP000 WAP001 WAP002 WAP003 WAP004 WAP005 WAP006 WAP007  \
# 0                 0    -64   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 1                 1    -64   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 2                 2    -79   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 3                 3    -79   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 4                 4    -78   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# ..              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 343             343    -82   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 344             344    -77   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 345             345    -77   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 346             346    -77   NULL   NULL   NULL   NULL   NULL   NULL   NULL
# 347             347    -77   NULL   NULL   NULL   NULL   NULL   NULL   NULL
#
#     WAP008  ...    coord_y coord_z floor building  site          tile user_id  \
# 0     NULL  ...  72.428346    NULL     1       11  NULL  crowd_tile_1       1
# 1     NULL  ...  73.902958    NULL     1       11  NULL  crowd_tile_1       1
# 2     NULL  ...  74.395074    NULL     1       11  NULL  crowd_tile_1       1
# 3     NULL  ...  73.526635    NULL     1       11  NULL  crowd_tile_1       1
# 4     NULL  ...  71.326591    NULL     1       11  NULL  crowd_tile_1       1
# ..     ...  ...        ...     ...   ...      ...   ...           ...     ...
# 343   NULL  ...  77.775208    NULL     1       11  NULL  crowd_tile_1       1
# 344   NULL  ...  76.994594    NULL     1       11  NULL  crowd_tile_1       1
# 345   NULL  ...  75.375542    NULL     1       11  NULL  crowd_tile_1       1
# 346   NULL  ...  74.320268    NULL     1       11  NULL  crowd_tile_1       1
# 347   NULL  ...  73.568567    NULL     1       11  NULL  crowd_tile_1       1
#
#     device_id       epoch       set
# 0           1  1462269732  training
# 1           1  1462269747  training
# 2           1  1462269759  training
# 3           1  1462269764  training
# 4           1  1462269776  training
# ..        ...         ...       ...
# 343         1  1462272597  training
# 344         1  1462272602  training
# 345         1  1462272609  training
# 346         1  1462272621  training
# 347         1  1462272627  training
#
# [348 rows x 169 columns]

# %%
# Generating the file places.csv

places = dataframe[['building', 'floor', 'site']].copy().drop_duplicates()
places.reset_index(inplace=True, drop=True)
places['floor_number'] = places['floor']
places = places[['building', 'floor', 'floor_number', 'site']]
places['site_height'] = 'NULL'
places['site_area'] = 'NULL'
places['floor_height'] = 3.7
places['floor_area'] = 'NULL'
places['building_area'] = 'NULL'

for col in places.columns:
    places[col] = places[col].astype(object)

places.to_csv(work_path + '/places.csv', sep=',', na_rep='NULL', index=False)

places
# Out:
#   building floor floor_number  site site_height site_area floor_height  \
# 0       11     1            1  NULL        NULL      NULL          3.7
#
#   floor_area building_area
# 0       NULL          NULL

# %%
# Generating the file tessellations.csv

tessellations = dataframe[['building', 'floor', 'site', 'tile']].copy().drop_duplicates()
tessellations['tessellation_type'] = 'crowd'
tessellations['coord_a_x'] = 'NULL'
tessellations['coord_a_y'] = 'NULL'
tessellations['coord_b_x'] = 'NULL'
tessellations['coord_b_y'] = 'NULL'
tessellations['coord_c_x'] = 'NULL'
tessellations['coord_c_y'] = 'NULL'
tessellations['coord_d_x'] = 'NULL'
tessellations['coord_d_y'] = 'NULL'
tessellations = tessellations[(tessellations['tile'] != 'NULL')]


for col in tessellations.columns:
    tessellations[col] = tessellations[col].astype(object)
    

tessellations.to_csv(work_path + '/tessellations.csv', sep=',', na_rep='NULL', index=False)

tessellations
# Out:
#   building floor  site          tile tessellation_type coord_a_x coord_a_y  \
# 0       11     1  NULL  crowd_tile_1             crowd      NULL      NULL
#
#   coord_b_x coord_b_y coord_c_x coord_c_y coord_d_x coord_d_y
# 0      NULL      NULL      NULL      NULL      NULL      NULL

# %%
# Generating the file fingerprints.csv

fingerprints = dataframe[['fingerprint_id', 'coord_x', 'coord_y', 'coord_z', 'user_id', 'device_id', 'epoch', 'set', 'building', 'floor', 'site', 'tile']].copy()
fingerprints['tile_id'] = fingerprints.merge(tessellations, on=['building', 'floor', 'site', 'tile'], how='left', suffixes=('_1', ''))['tile'].fillna('NULL').values
fingerprints = fingerprints[['fingerprint_id', 'coord_x', 'coord_y', 'coord_z', 'building', 'floor', 'site', 'tile', 'user_id', 'device_id', 'epoch', 'set']]
fingerprints['user_id'] = [x if x != 0 else 'NULL' for x in fingerprints['user_id']]
fingerprints['is_radio_map'] = [True if x == 'training' else False for x in fingerprints['set']]
fingerprints['preceded_by'] = 'NULL'
fingerprints['followed_by'] = 'NULL'
fingerprints['notes'] = 'NULL'
    

preceded_column = list(np.asarray(fingerprints['fingerprint_id']) - 1)
preceded_column[0] = 'NULL'
followed_column = list(np.asarray(fingerprints['fingerprint_id']) + 1)
followed_column[-1] = 'NULL'


for col in fingerprints.columns:
    fingerprints[col] = fingerprints[col].astype(object)
    

fingerprints['preceded_by'] = preceded_column
fingerprints['followed_by'] = followed_column

fingerprints.to_csv(work_path + '/fingerprints.csv', sep=',', na_rep='NULL', index=False)

fingerprints
# Out:
#     fingerprint_id  coord_x  coord_y coord_z building floor  site  \
# 0                0  80.2994  72.4283    NULL       11     1  NULL
# 1                1  79.2209   73.903    NULL       11     1  NULL
# 2                2  72.5338  74.3951    NULL       11     1  NULL
# 3                3  70.7535  73.5266    NULL       11     1  NULL
# 4                4  67.5547  71.3266    NULL       11     1  NULL
# ..             ...      ...      ...     ...      ...   ...   ...
# 343            343  74.8637  77.7752    NULL       11     1  NULL
# 344            344  73.5915  76.9946    NULL       11     1  NULL
# 345            345  74.2131  75.3755    NULL       11     1  NULL
# 346            346  72.6953  74.3203    NULL       11     1  NULL
# 347            347  71.2208  73.5686    NULL       11     1  NULL
#
#              tile user_id device_id       epoch       set is_radio_map  \
# 0    crowd_tile_1       1         1  1462269732  training         True
# 1    crowd_tile_1       1         1  1462269747  training         True
# 2    crowd_tile_1       1         1  1462269759  training         True
# 3    crowd_tile_1       1         1  1462269764  training         True
# 4    crowd_tile_1       1         1  1462269776  training         True
# ..            ...     ...       ...         ...       ...          ...
# 343  crowd_tile_1       1         1  1462272597  training         True
# 344  crowd_tile_1       1         1  1462272602  training         True
# 345  crowd_tile_1       1         1  1462272609  training         True
# 346  crowd_tile_1       1         1  1462272621  training         True
# 347  crowd_tile_1       1         1  1462272627  training         True
#
#     preceded_by followed_by notes
# 0          NULL           1  NULL
# 1             0           2  NULL
# 2             1           3  NULL
# 3             2           4  NULL
# 4             3           5  NULL
# ..          ...         ...   ...
# 343         342         344  NULL
# 344         343         345  NULL
# 345         344         346  NULL
# 346         345         347  NULL
# 347         346        NULL  NULL
#
# [348 rows x 16 columns]

# %%
# Generating the file wifi_obs.csv

wifi_obs = dataframe[[x for x in dataframe.columns if 'WAP' in x]].copy()
wifi_obs['fingerprint_id'] = dataframe['fingerprint_id']
wifi_obs = wifi_obs[['fingerprint_id'] + [x for x in dataframe.columns if 'WAP' in x]]

for col in wifi_obs.columns:
    wifi_obs[col] = wifi_obs[col].astype(object)
    
wifi_obs.columns = ["AP-" + x + "-NULL" if "WAP" in x else x for x in list(wifi_obs.columns)]

wifi_obs.to_csv(work_path + '/wifi_obs.csv', sep=',', na_rep='NULL', index=False)

wifi_obs
# Out:
#     fingerprint_id AP-WAP000-NULL AP-WAP001-NULL AP-WAP002-NULL  \
# 0                0            -64           NULL           NULL
# 1                1            -64           NULL           NULL
# 2                2            -79           NULL           NULL
# 3                3            -79           NULL           NULL
# 4                4            -78           NULL           NULL
# ..             ...            ...            ...            ...
# 343            343            -82           NULL           NULL
# 344            344            -77           NULL           NULL
# 345            345            -77           NULL           NULL
# 346            346            -77           NULL           NULL
# 347            347            -77           NULL           NULL
#
#     AP-WAP003-NULL AP-WAP004-NULL AP-WAP005-NULL AP-WAP006-NULL  \
# 0             NULL           NULL           NULL           NULL
# 1             NULL           NULL           NULL           NULL
# 2             NULL           NULL           NULL           NULL
# 3             NULL           NULL           NULL           NULL
# 4             NULL           NULL           NULL           NULL
# ..             ...            ...            ...            ...
# 343           NULL           NULL           NULL           NULL
# 344           NULL           NULL           NULL           NULL
# 345           NULL           NULL           NULL           NULL
# 346           NULL           NULL           NULL           NULL
# 347           NULL           NULL           NULL           NULL
#
#     AP-WAP007-NULL AP-WAP008-NULL  ... AP-WAP147-NULL AP-WAP148-NULL  \
# 0             NULL           NULL  ...           NULL           NULL
# 1             NULL           NULL  ...           NULL           NULL
# 2             NULL           NULL  ...           NULL           NULL
# 3             NULL           NULL  ...           NULL           NULL
# 4             NULL           NULL  ...            -87           NULL
# ..             ...            ...  ...            ...            ...
# 343           NULL           NULL  ...           NULL           NULL
# 344           NULL           NULL  ...           NULL           NULL
# 345           NULL           NULL  ...           NULL           NULL
# 346           NULL           NULL  ...           NULL           NULL
# 347           NULL           NULL  ...           NULL           NULL
#
#     AP-WAP149-NULL AP-WAP150-NULL AP-WAP151-NULL AP-WAP152-NULL  \
# 0             NULL           NULL           NULL           NULL
# 1             NULL           NULL           NULL           NULL
# 2             NULL           NULL           NULL           NULL
# 3             NULL           NULL           NULL           NULL
# 4             NULL           NULL            -96           NULL
# ..             ...            ...            ...            ...
# 343           NULL           NULL           NULL           NULL
# 344           NULL           NULL           NULL           NULL
# 345           NULL           NULL           NULL           NULL
# 346           NULL           NULL           NULL           NULL
# 347           NULL           NULL           NULL           NULL
#
#     AP-WAP153-NULL AP-WAP154-NULL AP-WAP155-NULL AP-WAP156-NULL
# 0             NULL           NULL           NULL           NULL
# 1             NULL           NULL           NULL           NULL
# 2             NULL           NULL           NULL           NULL
# 3             NULL           NULL           NULL           NULL
# 4             NULL           NULL           NULL           NULL
# ..             ...            ...            ...            ...
# 343           NULL           NULL           NULL           NULL
# 344           NULL           NULL           NULL           NULL
# 345           NULL           NULL           NULL           NULL
# 346           NULL           NULL           NULL           NULL
# 347           NULL           NULL           NULL           NULL
#
# [348 rows x 158 columns]
